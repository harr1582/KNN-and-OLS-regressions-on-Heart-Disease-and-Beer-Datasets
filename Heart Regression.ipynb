# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import sklearn
import seaborn as sns
from sklearn import neighbors
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\heart.csv')

print(df.head(3))
print (len(df))

print(df.dtypes)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 303
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
knn = neighbors.KNeighborsRegressor (n_neighbors = 5, weights = 'distance')


X = pd.DataFrame(df['chol']) #pd.DataFrame corrects a reshaping issue
Y = df.trestbps
knn.fit(X,Y)

T = np.arange(100, 600, 0.1)[:, np.newaxis]

Y_ = knn.predict(T)

plt.scatter(X, Y)
plt.plot(T, Y_, color = 'black')
plt.xlabel('Cholesterol')
plt.ylabel('Resting Blood Pressure')
plt.legend()
plt.show()

# %% [markdown]
# ## KNN regression doesn't seem helpful for this data.

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()


regr.fit(X, Y)

print('Coefficients: \n', regr.coef_)
print('Intercept: \n', regr.intercept_)

# Plot outputs
plt.scatter(X, Y, color='black')
plt.plot(X, regr.predict(X), color='blue', linewidth=3)
plt.show()
# Out:
# Coefficients:
#  [0.04167886]
# Intercept:
#  121.35975749430591

# %% [markdown]
# ##It appears a Multivatiate Linear regression gives a straight line but since the data is all over the place neither model
# seems to allow for any significant findings

# %%
df = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\beers.csv')

# %%
knn = neighbors.KNeighborsRegressor (n_neighbors = 10, weights='uniform')

X = pd.Dataframe(df['abv'])
Y = df['ibu']
knn.fit(X,Y)

T = np.arange(0, 100, .1) [:,np.newaxis]
Y_ = knn.predict(T)

plt.scatter(X,Y)
plt.plot(T,Y_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-21fb8273c57a> in <module>
#       1 knn = neighbors.KNeighborsRegressor (n_neighbors = 10, weights='uniform')
#       2
# ----> 3 X = pd.Dataframe(df['abv'])
#       4 Y = df['ibu']
#       5 knn.fit(X,Y)
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'
